# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series(data=np.random.normal(loc=0, scale=100, size=100000))
s
# Out:
# 0        274.737138
# 1         22.652443
# 2        157.347076
# 3       -144.822388
# 4         84.373327
#             ...
# 99995     29.679211
# 99996     29.550216
# 99997     17.783458
# 99998    -38.622912
# 99999     38.734098
# Length: 100000, dtype: float64

# %%
s.mean()
# Out:
# np.float64(0.04104648797775036)

# %%
s.std()
# Out:
# 99.78504305996766

# %%
s.median()
# Out:
# 0.007915737733677592

# %%
s.describe()
# Out:
# count    100000.000000
# mean          0.041046
# std          99.785043
# min        -432.168724
# 25%         -66.933701
# 50%           0.007916
# 75%          67.277595
# max         425.431830
# dtype: float64
